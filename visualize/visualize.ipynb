# %%
import pandas as pd
import matplotlib.pyplot as plt

excel_data = pd.read_excel('../Fitness.xlsx')
data = pd.DataFrame(excel_data)

plt.plot(data["Fitness"])
plt.title("Fitness")
plt.show()

# %%
excel_data = pd.read_excel('../Expectation.xlsx', header=None)

data = pd.DataFrame(excel_data)

teachers = data.iloc[:, 0]

expectation = data.iloc[:, 1]
plt.title("Expectation")
plt.bar(teachers, expectation)

plt.show()
